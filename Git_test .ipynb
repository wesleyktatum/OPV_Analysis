# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ofet_75c = pd.read_csv('/Users/wesleytatum/Desktop/75C.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-04d6b43cb7cd> in <module>()
# ----> 1 ofet_75c = pd.read_csv('/Users/wesleytatum/Desktop/75C.csv')
#
# /Users/elenashoushpanova/opt/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /Users/elenashoushpanova/opt/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /Users/elenashoushpanova/opt/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /Users/elenashoushpanova/opt/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /Users/elenashoushpanova/opt/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/Users/wesleytatum/Desktop/75C.csv' does not exist: b'/Users/wesleytatum/Desktop/75C.csv'

# %%
ofet_75c.head()
# Out:
#                     Sample  Temperature  Time    Scan Number    mu_lin  \
# 0  75C-5min_1-IdVg-2-Vd-20           75     5              1  0.002191
# 1                      NaN           75     5              2  0.002173
# 2                      NaN           75     5              3  0.002164
# 3                      NaN           75     5        Average       NaN
# 4                      NaN           75     5  Std Deviation       NaN
#
#    mu_lin_avg  mu_lin_SD     r_lin  r_lin_avg  r_lin_sd       on_off  \
# 0         NaN        NaN  0.570222        NaN       NaN  1088.293260
# 1         NaN        NaN  0.574836        NaN       NaN  1120.763142
# 2         NaN        NaN  0.595456        NaN       NaN  1149.690722
# 3    0.002176        NaN       NaN   0.580171       NaN          NaN
# 4         NaN   0.000014       NaN        NaN  0.013437          NaN
#
#     on_off_avg  on_off_sd         Vt     Vt_avg     Vt_sd
# 0          NaN        NaN -31.292441        NaN       NaN
# 1          NaN        NaN -31.563331        NaN       NaN
# 2          NaN        NaN -31.678356        NaN       NaN
# 3  1119.582374        NaN        NaN -31.511376       NaN
# 4          NaN  30.715757        NaN        NaN  0.198134

# %%
fig = plt.Figure(figsize = (8,8))

plt.plot(ofet_75c['Time'], ofet_75c['on_off'])

# %%
fig = plt.Figure(figsize = (8,8))

plt.plot(ofet_75c['Time'], ofet_75c['Vt'])
